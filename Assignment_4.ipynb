# %% [markdown]
#  1. What exactly is []?
# Ans:-
#
#      The empty list value, which is a list value that contains no items.
#
#
#  2. In a list of values stored in a variable called spam, how would you assign the value of 'hello' as the
#     third value? (Assume [2, 4, 6, 8, 10] are in spam.)
# Ans:-

# %%
spam = [2, 4, 6, 8, 10]
spam[2] = 'hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
#  3. What is the value of spam[int(int('3' * 2) / 11)]?
# Ans:-
#
#      The '3' * 2 is the string '33', which is passed to int() before being divided by 11. This eventually evaluates to 3.
#      Expressions can be used wherever values are used.
#
#
#
#
#  4. What is the value of spam [-1] ?
# Ans:-
#
#        Negative indexes count from the end.
#
#
#
#
#  5. What is the value of spam [:2] ? Lets pretend bacon has the list [3.14,'cat',11,'cat',True] for the next three questions.
# Ans:-
#
#      ['a', 'b']
#
#
#
#
#  6. What is the value of bacon.index('cat')?
# Ans:-
#
#       1 is the value of index.
#
#
#
#
#  7. How does bacon.append(99) change the look of the list value in bacon?
# Ans:-
#
#        bacon contains the list [3.14, 'cat', 11, 'cat', True].
#
#
#
#
#
#  8. How does bacon.remove('cat') change the look of the list in bacon?
# Ans:-
#
#       [3.14, 11, 'cat', True]
#
#
#
#
#
#  9. What are the list concatenation and list replication operators?
# Ans:-
#
#       The operator for list concatenation is +, while the operator for replication is *. (This is the same as for strings.)
#
#
#
#
#
#  10. What is difference between the list methods append() and insert()?
# ANS:-
#
#       While append() will add values only to the end of a list, insert() can add them anywhere in the list.
#
#
#
#
#
#
#  11. What are the two methods for removing items from a list?
# Ans:-
#
#         The methods are remove(), pop() and clear().
#
#
#
#
#
#   12. Describe how list values and string values are identical.
# Ans:-
#
#      The values that make up a list are called its elements. Lists are similar to strings, which are ordered collections of characters, except that        the elements of a list can have any type and for any one list, the items can be of different types.
#
#
#
#
#
#   13. Whats the difference between tuples and lists?
# Ans:-
#
#       The tuples are immutable and lists are mutable. tuples is denoted with () and lists are denoted with {}.
#       tubles are cannod be modified and list are modified.
#       the tuple is faster than the list because of static in nature. Lists are denoted by the square brackets but tuples are denoted as parenthesis.
#
#
#
#
#
#
#  14. How do you type a tuple value that only contains the integer 42?
# Ans:-
#      (42,) the comma is mandetory.
#
#
#
#
#
#
#  15. How do you get a list values tuple form? How do you get a tuple values list form?
# Ans:-
#
#      Using the tuple() built-in function
#      An iterable can be passed as an input to the tuple () function, which will convert it to a tuple object. If you want to convert a Python list to      a tuple, you can use the tuple() function to pass the full list as an argument, and it will return the tuple data type as an output.
#
#
#
#
#
#  16. Variables that "contain" list values are not necessarily lists themselves. Instead, what do they
#      contain?
# Ans:-
#
#        Variables will contain references to list values rather than list values themselves. But for strings and integer values, variables simply              contain the string or integer value.
#
#
#
#
#
#  17. How do you distinguish between copy.copy() and copy.deepcopy()?
# Ans:-
#
#     copy() create reference to original object. If you change copied object - you change the original object. . deepcopy() creates new object and does     real copying of original object to new one.
