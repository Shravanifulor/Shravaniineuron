# %% [markdown]
#   1) In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be
#      mathematical operators.
#
#     * :- multiplication operator use in python
#     "hello" :- it is a string operator which are use the word hello
#     -87.8 :- in python it is a float valuse
#     -: it is used to divids the valuse
#     / :- slash
#     +:- addition
#     6 :- int
#
#
#
#
#
#   2) What is difference between string and variable?
#
# Ans:-    String is a type of data which is used or closed  in single and double  quote  of string values so, we can fill up a variable.
#          Variable is a symbols that we can use to store data in a program.
#
#
#
#
#
#   3) Descibe three different data types?
#
# Ans:-
#
#     1)String:- a string is a charectors put in programming in a single and double code that is quotation marks in python.
#     2)List:- list is like a aarays, list can contain the data of different types and it a ordered sequence of item.
#     3)boolean:- ot is type provides  two built-in values, true and false values in python.
#     4)tuple:- tuple is collection of python objects. its just like list and tuple is immutable in python.
#     5)set:- set can be created by usisng the built-in set. in st, the order the order of elements is undefined.
#
#
#
#
#
#   4) What is an expression made up of? what do all expressions do?
#
# Ans:-
#
#     An expression is a combination of operators ans operands that is interpreted to produce some other value.
#     it is produce some other value. in the programming languvage, an expression is evaluated as per the procedence of its operators.
#
#
#
#
#
#   5) This assignments statements, like spam = 10. what is the diffrence between an expression and a statements?
#
# Ans:- an expression evaluates to a single value i.e., it is a combination of variables, operations ans values. a statements does not.
#
#
#
#
#
#
#   6) after running the following code, what does the variable bacon contain?
#
#     bacon = 22
#     bacon + 1
#
# Ans:- the bacon variable is set to 20. the bacon +1 expression does not reassign the value in bacon.
#
#
#
#
#
#
#   7) What should the values of the following two terms be?
#
#     'spam'+'spamspam'
#     'spam'
#
# Ans:- both expressions evaluated to the string 'spamspamspam'.
#
#
#
#
#
#   8) why is eggs valid a variable name while 100 is invalid?
#
# Ans:- variable names cannot begin with a number and eggs is not a number so, thats why its invalid.
#
#
#
#
#
#   9) What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans:- the int(), float() and str() functions will evaluated to the integer, floationg-point number and string version of the value passed to       them.
#
#
#
#
#
#   10) Why does this expression cause an error? How can you fix it?
#
#     'I have eaten ' + 99 + ' burritos.'
#
# Ans:- The expression causes an error because 99 is a integer, and only string can be concatenated to other strings with the + operator. the       currect way to written is 'i have eaten' + str(99)+'burritos'.
